# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

from tqdm import tqdm
from keras import utils
from sklearn.preprocessing import label_binarize
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D
from keras.optimizers import Adam

# %%
labels_all = pd.read_csv("dog_dataset/labels.csv")
print(labels_all.shape)
labels_all.head()
# Out:
# (10222, 2)
#                                  id             breed
# 0  000bec180eb18c7604dcecc8fe0dba07       boston_bull
# 1  001513dfcb2ffafc82cccf4d8bbaba97             dingo
# 2  001cdf01b096e06d78e9e5112d419397          pekinese
# 3  00214f311d5d2247d5dfe4fe24b2303d          bluetick
# 4  0021f9ceb3235effd7fcde7f7538ed62  golden_retriever

# %%
breeds_all = labels_all['breed']
breed_counts = breeds_all.value_counts()
breed_counts.head()
# Out:
# scottish_deerhound      126
# maltese_dog             117
# afghan_hound            116
# entlebucher             115
# bernese_mountain_dog    114
# Name: breed, dtype: int64

# %%
CLASS_NAMES = ['scottish_deerhound','maltese_dog','bernese_mountain_dog']
labels = labels_all[(labels_all['breed'].isin(CLASS_NAMES))]
labels.head()
# Out:
#                                    id                 breed
# 9    0042188c895a2f14ef64a918ed9c7b64    scottish_deerhound
# 12   00693b8bc2470375cc744a6391d397ec           maltese_dog
# 79   01e787576c003930f96c966f9c3e1d44    scottish_deerhound
# 90   022b34fd8734b39995a9f38a4f3e7b6b           maltese_dog
# 118  02d54f0dfb40038765e838459ae8c956  bernese_mountain_dog

# %%
# Creating numpy matrix with zeros
X_data = np.zeros((len(labels), 224, 224, 3), dtype='float32')
# One hot encoding
Y_data = label_binarize(labels['breed'], classes = CLASS_NAMES)

# Reading and converting image to numpy array and normalizing dataset
for i in tqdm(range(len(labels))):
    path = 'dog_dataset/train/%s.jpg' % labels.id.iloc[i]
    img = utils.load_img(path, target_size=(224, 224))
    img = utils.img_to_array(img)
    x = np.expand_dims(img.copy(), axis=0)
    X_data[i] = x / 255.0
    
# Printing train image and one hot encode shape & size
print('\nTrain Images shape: ',X_data.shape,' size: {:,}'.format(X_data.size))
print('One-hot encoded output shape: ',Y_data.shape,' size: {:,}'.format(Y_data.size))
# Out:
# 100%|██████████| 357/357 [00:00<00:00, 534.79it/s]
# Train Images shape:  (357, 224, 224, 3)  size: 53,738,496
# One-hot encoded output shape:  (357, 3)  size: 1,071

# %%
# Building the Model
model = Sequential()

model.add(Conv2D(filters = 64, kernel_size = (5,5), activation ='relu', input_shape = (224,224,3)))
model.add(MaxPool2D(pool_size=(2,2)))

model.add(Conv2D(filters = 32, kernel_size = (3,3), activation ='relu', kernel_regularizer = 'l2'))
model.add(MaxPool2D(pool_size=(2,2)))

model.add(Conv2D(filters = 16, kernel_size = (7,7), activation ='relu', kernel_regularizer = 'l2'))
model.add(MaxPool2D(pool_size=(2,2)))

model.add(Conv2D(filters = 8, kernel_size = (5,5), activation ='relu', kernel_regularizer = 'l2'))
model.add(MaxPool2D(pool_size=(2,2)))

model.add(Flatten())
model.add(Dense(128, activation = "relu", kernel_regularizer = 'l2'))
model.add(Dense(64, activation = "relu", kernel_regularizer = 'l2'))
model.add(Dense(len(CLASS_NAMES), activation = "softmax"))

model.compile(loss = 'categorical_crossentropy', optimizer = Adam(0.0001),metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 220, 220, 64)      4864
#
#  max_pooling2d (MaxPooling2D  (None, 110, 110, 64)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 108, 108, 32)      18464
#
#  max_pooling2d_1 (MaxPooling  (None, 54, 54, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 48, 48, 16)        25104
#
#  max_pooling2d_2 (MaxPooling  (None, 24, 24, 16)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 20, 20, 8)         3208
#
#  max_pooling2d_3 (MaxPooling  (None, 10, 10, 8)        0
#  2D)
#
#  flatten (Flatten)           (None, 800)               0
#
#  dense (Dense)               (None, 128)               102528
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 162,619
# Trainable params: 162,619
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Splitting the data set into training and testing data sets
X_train_and_val, X_test, Y_train_and_val, Y_test = train_test_split(X_data, Y_data, test_size = 0.1)
# Splitting the training data set into training and validation data sets
X_train, X_val, Y_train, Y_val = train_test_split(X_train_and_val, Y_train_and_val, test_size = 0.2)

# %%
# Training the model
epochs = 100
batch_size = 128

history = model.fit(X_train, Y_train, batch_size = batch_size, epochs = epochs, 
                    validation_data = (X_val, Y_val))
# Out:
# Epoch 1/100
# 2/2 [==============================] - 7s 1s/step - loss: 4.9294 - accuracy: 0.3125 - val_loss: 4.9058 - val_accuracy: 0.3538
# Epoch 2/100
# 2/2 [==============================] - 1s 356ms/step - loss: 4.9020 - accuracy: 0.3047 - val_loss: 4.8823 - val_accuracy: 0.3385
# Epoch 3/100
# 2/2 [==============================] - 1s 355ms/step - loss: 4.8761 - accuracy: 0.3086 - val_loss: 4.8581 - val_accuracy: 0.3846
# Epoch 4/100
# 2/2 [==============================] - 1s 368ms/step - loss: 4.8504 - accuracy: 0.3359 - val_loss: 4.8339 - val_accuracy: 0.3538
# Epoch 5/100
# 2/2 [==============================] - 1s 360ms/step - loss: 4.8248 - accuracy: 0.3672 - val_loss: 4.8093 - val_accuracy: 0.3846
# Epoch 6/100
# 2/2 [==============================] - 1s 363ms/step - loss: 4.7994 - accuracy: 0.3789 - val_loss: 4.7848 - val_accuracy: 0.3846
# Epoch 7/100
# 2/2 [==============================] - 1s 356ms/step - loss: 4.7737 - accuracy: 0.3906 - val_loss: 4.7614 - val_accuracy: 0.4154
# Epoch 8/100
# 2/2 [==============================] - 1s 361ms/step - loss: 4.7489 - accuracy: 0.4023 - val_loss: 4.7385 - val_accuracy: 0.4154
# Epoch 9/100
# 2/2 [==============================] - 1s 356ms/step - loss: 4.7224 - accuracy: 0.4141 - val_loss: 4.7147 - val_accuracy: 0.4000
# Epoch 10/100
# 2/2 [==============================] - 1s 355ms/step - loss: 4.6963 - accuracy: 0.4648 - val_loss: 4.6902 - val_accuracy: 0.4308
# Epoch 11/100
# 2/2 [==============================] - 1s 364ms/step - loss: 4.6701 - accuracy: 0.4766 - val_loss: 4.6662 - val_accuracy: 0.4462
# Epoch 12/100
# 2/2 [==============================] - 1s 358ms/step - loss: 4.6436 - accuracy: 0.5117 - val_loss: 4.6424 - val_accuracy: 0.4923
# Epoch 13/100
# 2/2 [==============================] - 1s 356ms/step - loss: 4.6156 - accuracy: 0.5078 - val_loss: 4.6178 - val_accuracy: 0.4154
# Epoch 14/100
# 2/2 [==============================] - 1s 356ms/step - loss: 4.5880 - accuracy: 0.5156 - val_loss: 4.5931 - val_accuracy: 0.3846
# Epoch 15/100
# 2/2 [==============================] - 1s 360ms/step - loss: 4.5595 - accuracy: 0.5234 - val_loss: 4.5662 - val_accuracy: 0.4769
# Epoch 74/100
# 2/2 [==============================] - 1s 368ms/step - loss: 2.9519 - accuracy: 0.9492 - val_loss: 3.4881 - val_accuracy: 0.7692
# Epoch 75/100
# 2/2 [==============================] - 1s 362ms/step - loss: 2.9529 - accuracy: 0.9336 - val_loss: 3.4404 - val_accuracy: 0.8000
# Epoch 76/100
# 2/2 [==============================] - 1s 360ms/step - loss: 2.9272 - accuracy: 0.9531 - val_loss: 3.4302 - val_accuracy: 0.8000
# Epoch 77/100
# 2/2 [==============================] - 1s 360ms/step - loss: 2.9218 - accuracy: 0.9258 - val_loss: 3.4493 - val_accuracy: 0.7846
# Epoch 78/100
# 2/2 [==============================] - 1s 360ms/step - loss: 2.9078 - accuracy: 0.9453 - val_loss: 3.4547 - val_accuracy: 0.7692
# Epoch 79/100
# 2/2 [==============================] - 1s 360ms/step - loss: 2.8814 - accuracy: 0.9492 - val_loss: 3.4390 - val_accuracy: 0.7692
# Epoch 80/100
# 2/2 [==============================] - 1s 366ms/step - loss: 2.8771 - accuracy: 0.9453 - val_loss: 3.4158 - val_accuracy: 0.7692
# Epoch 81/100
# 2/2 [==============================] - 1s 364ms/step - loss: 2.8592 - accuracy: 0.9609 - val_loss: 3.4604 - val_accuracy: 0.7538
# Epoch 82/100
# 2/2 [==============================] - 1s 361ms/step - loss: 2.8464 - accuracy: 0.9570 - val_loss: 3.4429 - val_accuracy: 0.7692
# Epoch 83/100
# 2/2 [==============================] - 1s 361ms/step - loss: 2.8268 - accuracy: 0.9531 - val_loss: 3.3989 - val_accuracy: 0.7846
# Epoch 84/100
# 2/2 [==============================] - 1s 375ms/step - loss: 2.8176 - accuracy: 0.9570 - val_loss: 3.4280 - val_accuracy: 0.7692
# Epoch 85/100
# 2/2 [==============================] - 1s 359ms/step - loss: 2.8039 - accuracy: 0.9492 - val_loss: 3.4473 - val_accuracy: 0.7692
# Epoch 86/100
# 2/2 [==============================] - 1s 360ms/step - loss: 2.7857 - accuracy: 0.9688 - val_loss: 3.4138 - val_accuracy: 0.7692
# Epoch 87/100
# 2/2 [==============================] - 1s 359ms/step - loss: 2.7759 - accuracy: 0.9648 - val_loss: 3.4003 - val_accuracy: 0.7538
# Epoch 88/100
# 2/2 [==============================] - 1s 374ms/step - loss: 2.7609 - accuracy: 0.9648 - val_loss: 3.4104 - val_accuracy: 0.7692
# Epoch 89/100
# 2/2 [==============================] - 1s 373ms/step - loss: 2.7449 - accuracy: 0.9766 - val_loss: 3.4319 - val_accuracy: 0.7538
# Epoch 90/100
# 2/2 [==============================] - 1s 362ms/step - loss: 2.7461 - accuracy: 0.9648 - val_loss: 3.4252 - val_accuracy: 0.7538
# Epoch 91/100
# 2/2 [==============================] - 1s 371ms/step - loss: 2.7201 - accuracy: 0.9688 - val_loss: 3.3836 - val_accuracy: 0.7692
# Epoch 92/100
# 2/2 [==============================] - 1s 371ms/step - loss: 2.7125 - accuracy: 0.9688 - val_loss: 3.4122 - val_accuracy: 0.7538
# Epoch 93/100
# 2/2 [==============================] - 1s 362ms/step - loss: 2.7020 - accuracy: 0.9688 - val_loss: 3.4179 - val_accuracy: 0.7538
# Epoch 94/100
# 2/2 [==============================] - 1s 359ms/step - loss: 2.6946 - accuracy: 0.9688 - val_loss: 3.4182 - val_accuracy: 0.7538
# Epoch 95/100
# 2/2 [==============================] - 1s 361ms/step - loss: 2.6734 - accuracy: 0.9805 - val_loss: 3.4066 - val_accuracy: 0.7538
# Epoch 96/100
# 2/2 [==============================] - 1s 371ms/step - loss: 2.6677 - accuracy: 0.9727 - val_loss: 3.3964 - val_accuracy: 0.7538
# Epoch 97/100
# 2/2 [==============================] - 1s 362ms/step - loss: 2.6552 - accuracy: 0.9727 - val_loss: 3.4037 - val_accuracy: 0.7538
# Epoch 98/100
# 2/2 [==============================] - 1s 369ms/step - loss: 2.6405 - accuracy: 0.9805 - val_loss: 3.4216 - val_accuracy: 0.7385
# Epoch 99/100
# 2/2 [==============================] - 1s 366ms/step - loss: 2.6361 - accuracy: 0.9766 - val_loss: 3.3852 - val_accuracy: 0.7538
# Epoch 100/100
# 2/2 [==============================] - 1s 361ms/step - loss: 2.6175 - accuracy: 0.9844 - val_loss: 3.4007 - val_accuracy: 0.7385

# %%
# Plot the training history
plt.figure(figsize=(12, 5))
plt.plot(history.history['accuracy'], color='r')
plt.plot(history.history['val_accuracy'], color='b')
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'val'])

plt.show()

# %%
Y_pred = model.predict(X_test)
score = model.evaluate(X_test, Y_test)
print('Accuracy over the test set: \n ', round((score[1]*100), 2), '%')
# Out:
# 2/2 [==============================] - 1s 99ms/step
# 2/2 [==============================] - 0s 6ms/step - loss: 3.0198 - accuracy: 0.8056
# Accuracy over the test set:
#   80.56 %

# %%
# Plotting image to compare
plt.imshow(X_test[1,:,:,:])
plt.show()

# Finding max value from predition list and comaparing original value vs predicted
print("Originally : ",labels['breed'][np.argmax(Y_test[2])])
print("Predicted : ",labels['breed'][np.argmax(Y_pred[2])])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.conda/envs/default/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3620             try:
# -> 3621                 return self._engine.get_loc(casted_key)
#    3622             except KeyError as err:
#
# ~/.conda/envs/default/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/.conda/envs/default/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_101/873315433.py in <cell line: 6>()
#       4
#       5 # Finding max value from predition list and comaparing original value vs predicted
# ----> 6 print("Originally : ",labels['breed'][np.argmax(Y_test[2])])
#       7 print("Predicted : ",labels['breed'][np.argmax(Y_pred[2])])
#
# ~/.conda/envs/default/lib/python3.9/site-packages/pandas/core/series.py in __getitem__(self, key)
#     956
#     957         elif key_is_scalar:
# --> 958             return self._get_value(key)
#     959
#     960         if is_hashable(key):
#
# ~/.conda/envs/default/lib/python3.9/site-packages/pandas/core/series.py in _get_value(self, label, takeable)
#    1067
#    1068         # Similar to Index.get_value, but we do not fall back to positional
# -> 1069         loc = self.index.get_loc(label)
#    1070         return self.index._get_values_for_loc(self, loc, label)
#    1071
#
# ~/.conda/envs/default/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3621                 return self._engine.get_loc(casted_key)
#    3622             except KeyError as err:
# -> 3623                 raise KeyError(key) from err
#    3624             except TypeError:
#    3625                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 1
